# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("../data/processed/cleaned_retail_data.csv")

df.head()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_11448\4035283554.py:5: DtypeWarning: Columns (0: Invoice) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("../data/processed/cleaned_retail_data.csv")
#   Invoice StockCode                          Description  Quantity  \
# 0  489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1  489434    79323P                   PINK CHERRY LIGHTS        12
# 2  489434    79323W                  WHITE CHERRY LIGHTS        12
# 3  489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4  489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
#
#            InvoiceDate  Price  Customer ID         Country  Sales
# 0  2009-12-01 07:45:00   6.95      13085.0  United Kingdom   83.4
# 1  2009-12-01 07:45:00   6.75      13085.0  United Kingdom   81.0
# 2  2009-12-01 07:45:00   6.75      13085.0  United Kingdom   81.0
# 3  2009-12-01 07:45:00   2.10      13085.0  United Kingdom  100.8
# 4  2009-12-01 07:45:00   1.25      13085.0  United Kingdom   30.0

# %%
total_revenue = df["Sales"].sum()
total_orders = df["Invoice"].nunique()
total_customers = df["Customer ID"].nunique()

print("Total Revenue:", round(total_revenue,2))
print("Total Orders:", total_orders)
print("Total Customers:", total_customers)
# Out:
# Total Revenue: 20972968.14
# Total Orders: 40082
# Total Customers: 5878

# %%
# Save CLV dataset
clv.to_csv("../data/processed/customer_clv.csv")

print("CLV dataset saved!")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 # Save CLV dataset
# ----> 2 clv.to_csv("../data/processed/customer_clv.csv")
#       3
#       4 print("CLV dataset saved!")
#
# NameError: name 'clv' is not defined
